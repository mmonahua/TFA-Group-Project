# %%
import pandas as pd
import numpy as np
datafile = "/Users/tanxinqiao/desktop/311_Service_Requests_2020.csv"
df = pd.read_csv(datafile)
# Out:
# /Users/tanxinqiao/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1          45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2          45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3          45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4          45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# ...             ...                     ...                     ...    ...
# 2587311    48536847  12/31/2020 12:00:00 AM  12/31/2020 02:10:48 PM  DOHMH
# 2587312    48537845  12/31/2020 12:00:00 AM  12/31/2020 02:10:13 PM  DOHMH
# 2587313    48536999  12/31/2020 12:00:00 AM  01/06/2021 12:00:01 AM  DOHMH
# 2587314    48538698  12/31/2020 12:00:00 AM  12/31/2020 12:00:01 AM  DOHMH
# 2587315    48543111  12/31/2020 12:00:00 AM  12/31/2020 12:00:01 AM  DOHMH
#
# ...

# %%
df = df.loc[df['Incident Zip'] == 10019.0]
df
# Out:
#          Unique Key            Created Date             Closed Date  \
# 1203       45286121  01/01/2020 04:51:14 AM  01/01/2020 06:00:17 AM
# 1220       45288147  01/01/2020 04:57:11 AM  01/01/2020 06:00:36 AM
# 1248       45287437  01/01/2020 05:09:05 AM  01/01/2020 06:34:04 AM
# 1281       45287784  01/01/2020 05:27:13 AM  01/01/2020 06:34:26 AM
# 1287       45287381  01/01/2020 05:28:53 AM  01/01/2020 06:33:44 AM
# ...             ...                     ...                     ...
# 2585520    48535090  12/30/2020 05:21:11 PM  12/30/2020 09:00:21 PM
# 2585734    48532031  12/30/2020 06:10:19 PM  12/31/2020 07:49:57 AM
# 2585741    48532024  12/30/2020 06:11:28 PM  12/31/2020 07:49:02 AM
# 2586622    48534884  12/30/2020 09:36:17 PM  12/30/2020 10:13:01 PM
# 2587215    48531281  12/30/2020 11:40:29 PM  12/31/2020 12:49:45 AM
#
#                                           Agency  \
# 1203                                        NYPD
# ...

# %%
df.describe()
# Out:
#          Unique Key  Incident Zip           BBL  X Coordinate (State Plane)  \
# count  1.519500e+04       15195.0  1.306500e+04                1.506900e+04
# mean   4.687639e+07       10019.0  1.008354e+09                9.881572e+05
# std    9.845793e+05           0.0  4.926679e+07                1.403693e+03
# min    4.528507e+07       10019.0  0.000000e+00                9.849580e+05
# 25%    4.596705e+07       10019.0  1.010410e+09                9.871620e+05
# 50%    4.685700e+07       10019.0  1.010600e+09                9.879660e+05
# 75%    4.775094e+07       10019.0  1.010780e+09                9.890850e+05
# max    5.217923e+07       10019.0  1.201060e+09                1.001025e+06
#
#        Y Coordinate (State Plane)      Latitude     Longitude
# count                 15069.00000  15069.000000  15069.000000
# mean                 218103.02827     40.765318    -73.985895
# std                     950.63339      0.002609      0.005067
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2', 'Address Type', 'City', 'Landmark', 'Facility Type', 'Status', 'Due Date', 'Resolution Description', 'Resolution Action Updated Date', 'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Open Data Channel Type', 'Park Facility Name', 'Park Borough', 'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Latitude', 'Longitude', 'Location']

# %%
top10 = df.groupby(df['Complaint Type']).size().sort_values(ascending=False).iloc[:10]
top10
# Out:
# Complaint Type
# Noise - Street/Sidewalk                1299
# Noise - Residential                    1144
# Homeless Person Assistance             1116
# Noise                                  1066
# Illegal Parking                         998
# HEAT/HOT WATER                          866
# Noise - Commercial                      811
# Non-Emergency Police Matter             776
# Homeless Street Condition               658
# NonCompliance with Phased Reopening     620
# dtype: int64
